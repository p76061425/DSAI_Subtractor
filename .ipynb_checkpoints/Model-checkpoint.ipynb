# %% [markdown]
# # DSAI-HW3

# %% [markdown]
# ## Import package

# %%
from keras.models import Sequential
from keras import layers
from keras.layers import LSTM, TimeDistributed, Dense, RepeatVector, Activation, BatchNormalization,Bidirectional
from keras.models import load_model
import numpy as np
from six.moves import range
# Out:
# C:\Users\eric\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Parameters Config

# %%
class colors:
    ok = '\033[92m'
    fail = '\033[91m'
    close = '\033[0m'

# %%
TRAINING_SIZE = 80000
DIGITS = 3
REVERSE = False
MAXLEN = DIGITS + 1 + DIGITS+6
chars = '0123456789-+xyzabc '
RNN = layers.LSTM
HIDDEN_SIZE = 128
BATCH_SIZE = 128
LAYERS = 1

# %% [markdown]
# ## Data Generation

# %%
# %%time
data = []
label = []
seen = set()

print('Generating data...')
while len(data) < TRAINING_SIZE:
    f = lambda: int(''.join(np.random.choice(list('0123456789')) for i in range(np.random.randint(1, DIGITS + 1))))
    a, b = f(), f()
    if(a<b):
        a,b = b,a
    
    operator = np.random.choice(list('+-'))
    
#     q = '{}-{}'.format(a, b)
    q = str(a) + operator + str(b)    
    
    if(operator == "-"):
        for i in range(len(str(b))):
            if(int(str(a)[-i-1]) - int(str(b)[-i-1]) < 0 ):
                if(i==0):
                    q+= "z"
                elif(i == 1):
                    q+= "y"
                else:
                    q+= "x"
                    
    if(operator == '+'):
        for i in range(len(str(b))):
            if(int(str(a)[-i-1]) + int(str(b)[-i-1]) > 10 ):
                if(i==0):
                    q+= "c"
                elif(i == 1):
                    q+= "b"
                else:
                    q+= "a"


    if(q not in seen):
        query = q + ' ' * (MAXLEN - len(q))
        seen.add(query)
        data.append(query)
        
        if(operator == "+"):
            ans = str(a+b)
        else:
            ans = str(a-b)
        
        ans += ' '* (DIGITS + 1 - len(ans))
        label.append(ans)
        
    
# print(data)
# print(label)
# Out:
# Generating data...
# Wall time: 4.65 s

# %% [markdown]
# ## Processing

# %%
class CharacterTable(object):
    def __init__(self, chars):
        self.chars = sorted(set(chars))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
    
    def encode(self, C, num_rows):
        x = np.zeros((num_rows, len(self.chars)))
        for i, c in enumerate(C):
            x[i, self.char_indices[c]] = 1
        return x
    
    def decode(self, x, calc_argmax=True):
        if calc_argmax:
            x = x.argmax(axis=-1)
        return "".join(self.indices_char[i] for i in x)

# %%
ctable = CharacterTable(chars)

print('Vectorization...')
x = np.zeros((len(data), MAXLEN, len(chars)))
y = np.zeros((len(label), DIGITS + 1, len(chars)))
for i, sentence in enumerate(data):
    x[i] = ctable.encode(sentence, MAXLEN)
for i, sentence in enumerate(label):
    y[i] = ctable.encode(sentence, DIGITS + 1)
    
# print(x.shape)
# print(y.shape)
# print(y)
# Out:
# Vectorization...

# %%
indices = np.arange(len(y))
np.random.shuffle(indices)
x = x[indices]
y = y[indices]

# train_test_split
train_x = x[:20000]
train_y = y[:20000]
test_x = x[20000:]
test_y = y[20000:]

split_at = len(train_x) - len(train_x) // 10
print(len(train_x))

(x_train, x_val) = train_x[:split_at], train_x[split_at:]
(y_train, y_val) = train_y[:split_at], train_y[split_at:]

print('Training Data:')
print(x_train.shape)
print(y_train.shape)

print('Validation Data:')
print(x_val.shape)
print(y_val.shape)

print('Testing Data:')
print(test_x.shape)
print(test_y.shape)
# Out:
# 20000
# Training Data:
# (18000, 13, 19)
# (18000, 4, 19)
# Validation Data:
# (2000, 13, 19)
# (2000, 4, 19)
# Testing Data:
# (60000, 13, 19)
# (60000, 4, 19)

# %% [markdown]
# ## Build Model

# %%
print('Build model...')
model = Sequential()

model.add(BatchNormalization(input_shape =(MAXLEN,len(chars))))
model.add(Bidirectional(RNN(HIDDEN_SIZE),merge_mode='concat'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(layers.RepeatVector(DIGITS + 1))
model.add(RNN(HIDDEN_SIZE, return_sequences=True))
model.add(layers.TimeDistributed(layers.Dense(len(chars))))
model.add(layers.Activation('softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model.summary()
# Out:
# Build model...
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization_1 (Batch (None, 13, 19)            76
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 256)               151552
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 4, 256)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 4, 128)            197120
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 4, 19)             2451
# _________________________________________________________________
# activation_2 (Activation)    (None, 4, 19)             0
# =================================================================
# Total params: 352,223
# Trainable params: 351,673
# Non-trainable params: 550
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
for iteration in range(100):
    print()
    print('-' * 50)
    print('Iteration', iteration)
    model.fit(x_train, y_train,
              batch_size=BATCH_SIZE,
              epochs=1,
              validation_data=(x_val, y_val))
    for i in range(10):
        ind = np.random.randint(0, len(x_val))
        rowx, rowy = x_val[np.array([ind])], y_val[np.array([ind])]
        preds = model.predict_classes(rowx, verbose=0)
        q = ctable.decode(rowx[0])
        correct = ctable.decode(rowy[0])
        guess = ctable.decode(preds[0], calc_argmax=False)
        print('Q', q[::-1] if REVERSE else q, end=' ')
        print('T', correct, end=' ')
        if correct == guess:
            print(colors.ok + '☑' + colors.close, end=' ')
        else:
            print(colors.fail + '☒' + colors.close, end=' ')
        print(guess)
# Out:
# --------------------------------------------------
# Iteration 0
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 11s 624us/step - loss: 1.4844 - acc: 0.5120 - val_loss: 1.1892 - val_acc: 0.5933
# Q 348+5c        T 353  ☒ 333
# Q 4+0           T 4    ☑ 4
# Q 8+6c          T 14   ☒ 11
# Q 875-2         T 873  ☒ 885
# Q 852-86zy      T 766  ☒ 777
# Q 112-68zy      T 44   ☒ 17
# Q 954+3         T 957  ☒ 999
# Q 292+6         T 298  ☒ 299
# Q 99+12c        T 111  ☑ 111
# Q 177-2         T 175  ☒ 111
#
# --------------------------------------------------
# Iteration 1
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 491us/step - loss: 0.9975 - acc: 0.6517 - val_loss: 0.8653 - val_acc: 0.7006
# Q 899+4c        T 903  ☑ 903
# Q 816-7z        T 809  ☒ 855
# Q 48+7c         T 55   ☑ 55
# Q 339+90b       T 429  ☒ 335
# Q 35+2          T 37   ☑ 37
# Q 567-566       T 1    ☒ 11
# Q 24+10         T 34   ☒ 22
# Q 6-5           T 1    ☑ 1
# Q 917-8z        T 909  ☒ 922
# Q 448-8         T 440  ☒ 442
#
# --------------------------------------------------
# Iteration 2
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 0.7361 - acc: 0.7514 - val_loss: 0.6294 - val_acc: 0.7838
# Q 694+99cb      T 793  ☒ 755
# Q 985-162       T 823  ☒ 933
# Q 5+4           T 9    ☑ 9
# Q 677+5c        T 682  ☒ 662
# Q 960+1         T 961  ☑ 961
# Q 59+2c         T 61   ☑ 61
# Q 46+0          T 46   ☑ 46
# Q 159-6         T 153  ☒ 115
# Q 9-0           T 9    ☑ 9
# Q 65-4          T 61   ☑ 61
#
# --------------------------------------------------
# Iteration 3
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 0.5339 - acc: 0.8236 - val_loss: 0.4537 - val_acc: 0.8501
# Q 512-2         T 510  ☒ 500
# Q 57+5c         T 62   ☑ 62
# Q 9-8           T 1    ☑ 1
# Q 694-3         T 691  ☑ 691
# Q 863+66b       T 929  ☒ 959
# Q 9+9c          T 18   ☑ 18
# Q 566-493y      T 73   ☒ 14
# Q 168+8c        T 176  ☒ 166
# Q 665-44        T 621  ☒ 611
# Q 6+0           T 6    ☑ 6
#
# --------------------------------------------------
# Iteration 4
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 502us/step - loss: 0.3898 - acc: 0.8741 - val_loss: 0.3429 - val_acc: 0.8861
# Q 988+927ca     T 1915 ☒ 1117
# Q 629-181y      T 448  ☒ 398
# Q 745+37c       T 782  ☒ 702
# Q 979-47        T 932  ☒ 922
# Q 43-1          T 42   ☑ 42
# Q 92-0          T 92   ☑ 92
# Q 577+5c        T 582  ☑ 582
# Q 8+0           T 8    ☑ 8
# Q 485-1         T 484  ☑ 484
# Q 330-3z        T 327  ☑ 327
#
# --------------------------------------------------
# Iteration 5
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 490us/step - loss: 0.2925 - acc: 0.9070 - val_loss: 0.2919 - val_acc: 0.9035
# Q 954+3         T 957  ☑ 957
# Q 61-15z        T 46   ☒ 56
# Q 3+1           T 4    ☑ 4
# Q 78+50b        T 128  ☒ 138
# Q 720-44zy      T 676  ☒ 666
# Q 940-0         T 940  ☒ 9400
# Q 97-3          T 94   ☑ 94
# Q 7+2           T 9    ☑ 9
# Q 203+48c       T 251  ☑ 251
# Q 68+5c         T 73   ☑ 73
#
# --------------------------------------------------
# Iteration 6
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 0.2341 - acc: 0.9244 - val_loss: 0.2284 - val_acc: 0.9227
# Q 5+3           T 8    ☑ 8
# Q 12-9z         T 3    ☑ 3
# Q 80-4z         T 76   ☑ 76
# Q 655-3         T 652  ☑ 652
# Q 4+4           T 8    ☑ 8
# Q 734-200       T 534  ☒ 544
# Q 917+6c        T 923  ☑ 923
# Q 50+49         T 99   ☒ 999
# Q 637-5         T 632  ☑ 632
# Q 129+58c       T 187  ☑ 187
#
# --------------------------------------------------
# Iteration 7
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 509us/step - loss: 0.1881 - acc: 0.9391 - val_loss: 0.1935 - val_acc: 0.9352
# Q 72-2          T 70   ☑ 70
# Q 3-1           T 2    ☑ 2
# Q 213-57zy      T 156  ☒ 166
# Q 7-5           T 2    ☑ 2
# Q 6-5           T 1    ☑ 1
# Q 6+6c          T 12   ☑ 12
# Q 546-0         T 546  ☑ 546
# Q 562+6         T 568  ☑ 568
# Q 32-0          T 32   ☑ 32
# Q 896-6         T 890  ☑ 890
#
# --------------------------------------------------
# Iteration 8
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 513us/step - loss: 0.1583 - acc: 0.9496 - val_loss: 0.1763 - val_acc: 0.9399
# Q 57+1          T 58   ☑ 58
# Q 88-1          T 87   ☑ 87
# Q 375+26c       T 401  ☑ 401
# Q 304+259c      T 563  ☒ 583
# Q 7-6           T 1    ☑ 1
# Q 251-0         T 251  ☑ 251
# Q 546-0         T 546  ☑ 546
# Q 815+4         T 819  ☑ 819
# Q 61-8z         T 53   ☑ 53
# Q 68-36         T 32   ☑ 32
#
# --------------------------------------------------
# Iteration 9
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 506us/step - loss: 0.1313 - acc: 0.9583 - val_loss: 0.1536 - val_acc: 0.9456
# Q 89-5          T 84   ☑ 84
# Q 788+699cba    T 1487 ☒ 1477
# Q 270+5         T 275  ☑ 275
# Q 34-1          T 33   ☑ 33
# Q 274-2         T 272  ☑ 272
# Q 141+4         T 145  ☑ 145
# Q 232-9z        T 223  ☑ 223
# Q 337-4         T 333  ☑ 333
# Q 181+33b       T 214  ☑ 214
# Q 383+92b       T 475  ☒ 455
#
# --------------------------------------------------
# Iteration 10
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 0.1114 - acc: 0.9649 - val_loss: 0.1372 - val_acc: 0.9525
# Q 869-249       T 620  ☒ 630
# Q 26-2          T 24   ☑ 24
# Q 57+5c         T 62   ☑ 62
# Q 9+8c          T 17   ☑ 17
# Q 7-7           T 0    ☑ 0
# Q 525+21        T 546  ☑ 546
# Q 870-393zy     T 477  ☑ 477
# Q 63+5          T 68   ☑ 68
# Q 95+9c         T 104  ☑ 104
# Q 101-59zy      T 42   ☑ 42
#
# --------------------------------------------------
# Iteration 11
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 497us/step - loss: 0.0954 - acc: 0.9711 - val_loss: 0.1462 - val_acc: 0.9478
# Q 97+11         T 108  ☑ 108
# Q 802-4z        T 798  ☑ 798
# Q 98-7          T 91   ☑ 91
# Q 76+5c         T 81   ☑ 81
# Q 934-8z        T 926  ☑ 926
# Q 9-1           T 8    ☑ 8
# Q 48+9c         T 57   ☑ 57
# Q 55+2          T 57   ☑ 57
# Q 9+9c          T 18   ☑ 18
# Q 399+96cb      T 495  ☒ 485
#
# --------------------------------------------------
# Iteration 12
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 498us/step - loss: 0.0849 - acc: 0.9745 - val_loss: 0.1166 - val_acc: 0.9576
# Q 6-3           T 3    ☑ 3
# Q 49-4          T 45   ☑ 45
# Q 28-2          T 26   ☑ 26
# Q 876+408ca     T 1284 ☒ 1294
# Q 96+4          T 100  ☑ 100
# Q 9+8c          T 17   ☑ 17
# Q 50-31z        T 19   ☑ 19
# Q 160-4z        T 156  ☑ 156
# Q 470-6z        T 464  ☑ 464
# Q 77-2          T 75   ☑ 75
#
# --------------------------------------------------
# Iteration 13
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 482us/step - loss: 0.0702 - acc: 0.9797 - val_loss: 0.1153 - val_acc: 0.9586
# Q 909-4         T 905  ☑ 905
# Q 65-6z         T 59   ☑ 59
# Q 8-2           T 6    ☑ 6
# Q 33+5          T 38   ☑ 38
# Q 980+0         T 980  ☑ 980
# Q 65-2          T 63   ☑ 63
# Q 504+0         T 504  ☑ 504
# Q 84-41         T 43   ☑ 43
# Q 1+0           T 1    ☑ 1
# Q 9+8c          T 17   ☑ 17
#
# --------------------------------------------------
# Iteration 14
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 513us/step - loss: 0.0636 - acc: 0.9815 - val_loss: 0.1109 - val_acc: 0.9616
# Q 76+5c         T 81   ☑ 81
# Q 16-7z         T 9    ☑ 9
# Q 50-4z         T 46   ☑ 46
# Q 171+95b       T 266  ☑ 266
# Q 825+3         T 828  ☑ 828
# Q 291-72z       T 219  ☑ 219
# Q 529-520       T 9    ☒ 29
# Q 57+5c         T 62   ☑ 62
# Q 866-546       T 320  ☒ 310
# Q 311+7         T 318  ☑ 318
#
# --------------------------------------------------
# Iteration 15
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 497us/step - loss: 0.0551 - acc: 0.9851 - val_loss: 0.1076 - val_acc: 0.9625
# Q 729+56c       T 785  ☒ 775
# Q 306-61y       T 245  ☒ 255
# Q 241-48z       T 193  ☒ 203
# Q 115+5         T 120  ☑ 120
# Q 68-0          T 68   ☑ 68
# Q 585+62b       T 647  ☑ 647
# Q 9-5           T 4    ☑ 4
# Q 93-73         T 20   ☑ 20
# Q 781-777z      T 4    ☒ 104
# Q 304-8z        T 296  ☑ 296
#
# --------------------------------------------------
# Iteration 16
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 0.0492 - acc: 0.9865 - val_loss: 0.1078 - val_acc: 0.9632
# Q 176+57cb      T 233  ☒ 225
# Q 735+65        T 800  ☑ 800
# Q 822-3z        T 819  ☑ 819
# Q 792-315z      T 477  ☑ 477
# Q 8-1           T 7    ☑ 7
# Q 703-53y       T 650  ☑ 650
# Q 448-8         T 440  ☑ 440
# Q 67+33         T 100  ☑ 100
# Q 425-2         T 423  ☑ 423
# Q 972+39c       T 1011 ☑ 1011
#
# --------------------------------------------------
# Iteration 17
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 0.0403 - acc: 0.9899 - val_loss: 0.1034 - val_acc: 0.9644
# Q 648-14        T 634  ☑ 634
# Q 23+6          T 29   ☑ 29
# Q 7-5           T 2    ☑ 2
# Q 55-4          T 51   ☑ 51
# Q 171+95b       T 266  ☑ 266
# Q 683+3         T 686  ☑ 686
# Q 23+5          T 28   ☑ 28
# Q 989+8c        T 997  ☑ 997
# Q 87+2          T 89   ☑ 89
# Q 63-0          T 63   ☑ 63
#
# --------------------------------------------------
# Iteration 18
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 502us/step - loss: 0.0392 - acc: 0.9903 - val_loss: 0.0984 - val_acc: 0.9656
# Q 990-754z      T 236  ☒ 226
# Q 373-359z      T 14   ☒ 144
# Q 13+7          T 20   ☑ 20
# Q 753-6z        T 747  ☑ 747
# Q 28-4          T 24   ☑ 24
# Q 0-0           T 0    ☑ 0
# Q 38+18c        T 56   ☑ 56
# Q 80-8z         T 72   ☑ 72
# Q 549+7c        T 556  ☑ 556
# Q 81-2z         T 79   ☑ 79
#
# --------------------------------------------------
# Iteration 19
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 503us/step - loss: 0.0297 - acc: 0.9934 - val_loss: 0.0934 - val_acc: 0.9695
# Q 765-234       T 531  ☒ 541
# Q 568-98y       T 470  ☒ 460
# Q 961-47z       T 914  ☑ 914
# Q 180+91b       T 271  ☑ 271
# Q 98-63         T 35   ☑ 35
# Q 860+23        T 883  ☑ 883
# Q 810-0         T 810  ☑ 810
# Q 853-98zy      T 755  ☑ 755
# Q 205+91        T 296  ☑ 296
# Q 975-43        T 932  ☑ 932
#
# --------------------------------------------------
# Iteration 20
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 503us/step - loss: 0.0236 - acc: 0.9959 - val_loss: 0.0925 - val_acc: 0.9696
# Q 694-3         T 691  ☑ 691
# Q 961+79b       T 1040 ☒ 1050
# Q 756-21        T 735  ☑ 735
# Q 371+67b       T 438  ☒ 448
# Q 44+3          T 47   ☑ 47
# Q 12+3          T 15   ☑ 15
# Q 12+3          T 15   ☑ 15
# Q 656-69zy      T 587  ☒ 589
# Q 95-34         T 61   ☑ 61
# Q 85-18z        T 67   ☑ 67
#
# --------------------------------------------------
# Iteration 21
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 0.0244 - acc: 0.9954 - val_loss: 0.0977 - val_acc: 0.9674
# Q 971+3         T 974  ☑ 974
# Q 770+732a      T 1502 ☒ 1492
# Q 727+63        T 790  ☒ 800
# Q 94+6          T 100  ☑ 100
# Q 895+466cba    T 1361 ☒ 1431
# Q 89-5          T 84   ☑ 84
# Q 71-65z        T 6    ☑ 6
# Q 60-5z         T 55   ☑ 55
# Q 502+78        T 580  ☑ 580
# Q 313-73y       T 240  ☑ 240
#
# --------------------------------------------------
# Iteration 22
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 497us/step - loss: 0.0219 - acc: 0.9955 - val_loss: 0.0955 - val_acc: 0.9680
# Q 952+4         T 956  ☑ 956
# Q 96-2          T 94   ☑ 94
# Q 28-4          T 24   ☑ 24
# Q 9-1           T 8    ☑ 8
# Q 78-5          T 73   ☑ 73
# Q 488-95y       T 393  ☑ 393
# Q 90+5          T 95   ☑ 95
# Q 3+0           T 3    ☑ 3
# Q 52-2          T 50   ☑ 50
# Q 558-6         T 552  ☑ 552
#
# --------------------------------------------------
# Iteration 23
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 493us/step - loss: 0.0240 - acc: 0.9948 - val_loss: 0.0970 - val_acc: 0.9689
# Q 4+2           T 6    ☑ 6
# Q 846-6         T 840  ☑ 840
# Q 393+8c        T 401  ☑ 401
# Q 756+77cb      T 833  ☑ 833
# Q 89-64         T 25   ☑ 25
# Q 47-2          T 45   ☑ 45
# Q 125+122       T 247  ☒ 347
# Q 738-93y       T 645  ☑ 645
# Q 263+107       T 370  ☒ 360
# Q 199-4         T 195  ☑ 195
#
# --------------------------------------------------
# Iteration 24
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 493us/step - loss: 0.0191 - acc: 0.9961 - val_loss: 0.0892 - val_acc: 0.9731
# Q 51-31         T 20   ☑ 20
# Q 781-777z      T 4    ☒ 104
# Q 892-6z        T 886  ☑ 886
# Q 7-6           T 1    ☑ 1
# Q 82+5          T 87   ☑ 87
# Q 95+5          T 100  ☑ 100
# Q 3+0           T 3    ☑ 3
# Q 497+31b       T 528  ☑ 528
# Q 762+327       T 1089 ☑ 1089
# Q 940-0         T 940  ☑ 940
#
# --------------------------------------------------
# Iteration 25
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 491us/step - loss: 0.0143 - acc: 0.9977 - val_loss: 0.0856 - val_acc: 0.9729
# Q 49+3c         T 52   ☑ 52
# Q 758+397cb     T 1155 ☒ 1115
# Q 88-5          T 83   ☑ 83
# Q 909-4         T 905  ☑ 905
# Q 842-8z        T 834  ☑ 834
# Q 74+58cb       T 132  ☑ 132
# Q 5+3           T 8    ☑ 8
# Q 64+5          T 69   ☑ 69
# Q 229-3         T 226  ☑ 226
# Q 917+6c        T 923  ☑ 923
#
# --------------------------------------------------
# Iteration 26
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 8s 469us/step - loss: 0.0137 - acc: 0.9974 - val_loss: 0.0905 - val_acc: 0.9719
# Q 755+84b       T 839  ☑ 839
# Q 765-106z      T 659  ☑ 659
# Q 15+3          T 18   ☑ 18
# Q 3-1           T 2    ☑ 2
# Q 86+5c         T 91   ☑ 91
# Q 9+3c          T 12   ☑ 12
# Q 69+7c         T 76   ☑ 76
# Q 35+4          T 39   ☑ 39
# Q 70+5          T 75   ☑ 75
# Q 47+2          T 49   ☑ 49
#
# --------------------------------------------------
# Iteration 27
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 484us/step - loss: 0.0177 - acc: 0.9961 - val_loss: 0.0934 - val_acc: 0.9691
# Q 441+84b       T 525  ☒ 535
# Q 8+0           T 8    ☑ 8
# Q 769-23        T 746  ☑ 746
# Q 880-8z        T 872  ☑ 872
# Q 65-47z        T 18   ☑ 18
# Q 909-4         T 905  ☑ 905
# Q 50+6          T 56   ☑ 56
# Q 940+6         T 946  ☑ 946
# Q 86+9c         T 95   ☑ 95
# Q 75-20         T 55   ☑ 55
#
# --------------------------------------------------
# Iteration 28
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 0.0166 - acc: 0.9964 - val_loss: 0.0953 - val_acc: 0.9687
# Q 773-0         T 773  ☑ 773
# Q 285+105       T 390  ☒ 380
# Q 158-83y       T 75   ☑ 75
# Q 6-5           T 1    ☑ 1
# Q 6-3           T 3    ☑ 3
# Q 74+29c        T 103  ☑ 103
# Q 853+853a      T 1706 ☒ 1786
# Q 112-68zy      T 44   ☑ 44
# Q 735+65        T 800  ☑ 800
# Q 84+2          T 86   ☑ 86
#
# --------------------------------------------------
# Iteration 29
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 497us/step - loss: 0.0203 - acc: 0.9947 - val_loss: 0.1075 - val_acc: 0.9669
# Q 825+2         T 827  ☑ 827
# Q 17-2          T 15   ☑ 15
# Q 837+13        T 850  ☑ 850
# Q 2-1           T 1    ☑ 1
# Q 67+51b        T 118  ☑ 118
# Q 8-3           T 5    ☑ 5
# Q 7+6c          T 13   ☑ 13
# Q 84-4          T 80   ☑ 80
# Q 561-29z       T 532  ☑ 532
# Q 979-47        T 932  ☑ 932
#
# --------------------------------------------------
# Iteration 30
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 0.0118 - acc: 0.9979 - val_loss: 0.0870 - val_acc: 0.9732
# Q 422-95zy      T 327  ☑ 327
# Q 66+6c         T 72   ☑ 72
# Q 160+86b       T 246  ☒ 256
# Q 153-8z        T 145  ☑ 145
# Q 36+0          T 36   ☑ 36
# Q 9-9           T 0    ☑ 0
# Q 490+5         T 495  ☑ 495
# Q 548+6c        T 554  ☑ 554
# Q 586-20        T 566  ☑ 566
# Q 979-254       T 725  ☒ 745
#
# --------------------------------------------------
# Iteration 31
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 0.0104 - acc: 0.9978 - val_loss: 0.0942 - val_acc: 0.9719
# Q 93+2          T 95   ☑ 95
# Q 7+3           T 10   ☑ 10
# Q 727+63        T 790  ☑ 790
# Q 314-6z        T 308  ☑ 308
# Q 80-75z        T 5    ☑ 5
# Q 536+4         T 540  ☑ 540
# Q 8-2           T 6    ☑ 6
# Q 64+5          T 69   ☑ 69
# Q 70-40         T 30   ☑ 30
# Q 986-181       T 805  ☒ 715
#
# --------------------------------------------------
# Iteration 32
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 0.0087 - acc: 0.9985 - val_loss: 0.0826 - val_acc: 0.9755
# Q 23+1          T 24   ☑ 24
# Q 20+9          T 29   ☑ 29
# Q 71-9z         T 62   ☑ 62
# Q 8+7c          T 15   ☑ 15
# Q 106+62        T 168  ☑ 168
# Q 810-0         T 810  ☑ 810
# Q 515-66zy      T 449  ☒ 439
# Q 476+89cb      T 565  ☑ 565
# Q 292-8z        T 284  ☑ 284
# Q 904-258zy     T 646  ☒ 656
#
# --------------------------------------------------
# Iteration 33
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 504us/step - loss: 0.0063 - acc: 0.9990 - val_loss: 0.0818 - val_acc: 0.9748
# Q 72+0          T 72   ☑ 72
# Q 68-8          T 60   ☑ 60
# Q 8-2           T 6    ☑ 6
# Q 9-6           T 3    ☑ 3
# Q 695-81        T 614  ☑ 614
# Q 104+57c       T 161  ☑ 161
# Q 564-1         T 563  ☑ 563
# Q 4+3           T 7    ☑ 7
# Q 956+2         T 958  ☑ 958
# Q 44-0          T 44   ☑ 44
#
# --------------------------------------------------
# Iteration 34
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 504us/step - loss: 0.0054 - acc: 0.9993 - val_loss: 0.0838 - val_acc: 0.9734
# Q 437+5c        T 442  ☑ 442
# Q 49+2c         T 51   ☑ 51
# Q 660+7         T 667  ☑ 667
# Q 29-7          T 22   ☑ 22
# Q 959-9         T 950  ☑ 950
# Q 683+3         T 686  ☑ 686
# Q 53+1          T 54   ☑ 54
# Q 847-163y      T 684  ☒ 784
# Q 95+2          T 97   ☑ 97
# Q 789+3c        T 792  ☑ 792
#
# --------------------------------------------------
# Iteration 35
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 503us/step - loss: 0.0114 - acc: 0.9974 - val_loss: 0.0941 - val_acc: 0.9729
# Q 846+483ba     T 1329 ☑ 1329
# Q 421-40y       T 381  ☒ 371
# Q 87+3          T 90   ☑ 90
# Q 656-69zy      T 587  ☑ 587
# Q 902-8z        T 894  ☑ 894
# Q 0-0           T 0    ☑ 0
# Q 729-4         T 725  ☑ 725
# Q 3+0           T 3    ☑ 3
# Q 853+853a      T 1706 ☒ 176
# Q 0-0           T 0    ☑ 0
#
# --------------------------------------------------
# Iteration 36
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 0.0172 - acc: 0.9952 - val_loss: 0.1052 - val_acc: 0.9691
# Q 50-4z         T 46   ☑ 46
# Q 339+90b       T 429  ☑ 429
# Q 58-1          T 57   ☑ 57
# Q 41-2z         T 39   ☑ 39
# Q 968+43c       T 1011 ☒ 1001
# Q 987+462ba     T 1449 ☑ 1449
# Q 15-9z         T 6    ☑ 6
# Q 154-11        T 143  ☑ 143
# Q 76+5c         T 81   ☑ 81
# Q 284-4         T 280  ☑ 280
#
# --------------------------------------------------
# Iteration 37
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 0.0189 - acc: 0.9946 - val_loss: 0.0923 - val_acc: 0.9716
# Q 785+47cb      T 832  ☑ 832
# Q 6+2           T 8    ☑ 8
# Q 38+4c         T 42   ☑ 42
# Q 448-8         T 440  ☑ 440
# Q 78+30         T 108  ☑ 108
# Q 78-4          T 74   ☑ 74
# Q 0-0           T 0    ☑ 0
# Q 726+58c       T 784  ☑ 784
# Q 59+8c         T 67   ☑ 67
# Q 27+4c         T 31   ☑ 31
#
# --------------------------------------------------
# Iteration 38
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 501us/step - loss: 0.0093 - acc: 0.9980 - val_loss: 0.0873 - val_acc: 0.9746
# Q 31+0          T 31   ☑ 31
# Q 558-6         T 552  ☑ 552
# Q 41-2z         T 39   ☑ 39
# Q 86+23         T 109  ☑ 109
# Q 92+9c         T 101  ☑ 101
# Q 13+4          T 17   ☑ 17
# Q 79-9          T 70   ☑ 70
# Q 899+7c        T 906  ☑ 906
# Q 9-3           T 6    ☑ 6
# Q 566-16        T 550  ☑ 550
#
# --------------------------------------------------
# Iteration 39
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 485us/step - loss: 0.0053 - acc: 0.9991 - val_loss: 0.0891 - val_acc: 0.9743
# Q 77-6          T 71   ☑ 71
# Q 175-2         T 173  ☑ 173
# Q 996-99z       T 897  ☑ 897
# Q 65-19z        T 46   ☑ 46
# Q 84-41         T 43   ☑ 43
# Q 254-2         T 252  ☑ 252
# Q 94-6z         T 88   ☑ 88
# Q 50+6          T 56   ☑ 56
# Q 89-64         T 25   ☑ 25
# Q 806-586y      T 220  ☑ 220
#
# --------------------------------------------------
# Iteration 40
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 493us/step - loss: 0.0039 - acc: 0.9995 - val_loss: 0.0821 - val_acc: 0.9760
# Q 52-42         T 10   ☑ 10
# Q 751-74zy      T 677  ☑ 677
# Q 84-41         T 43   ☑ 43
# Q 418-266y      T 152  ☒ 172
# Q 368+9c        T 377  ☑ 377
# Q 807+3         T 810  ☒ 820
# Q 96-44         T 52   ☑ 52
# Q 992-74z       T 918  ☑ 918
# Q 80-27z        T 53   ☑ 53
# Q 28-4          T 24   ☑ 24
#
# --------------------------------------------------
# Iteration 41
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 503us/step - loss: 0.0059 - acc: 0.9988 - val_loss: 0.0928 - val_acc: 0.9726
# Q 7+1           T 8    ☑ 8
# Q 694-3         T 691  ☑ 691
# Q 40-2z         T 38   ☑ 38
# Q 927-727       T 200  ☒ 220
# Q 120-3z        T 117  ☑ 117
# Q 9+5c          T 14   ☑ 14
# Q 773+92b       T 865  ☑ 865
# Q 7+3           T 10   ☑ 10
# Q 221+6         T 227  ☑ 227
# Q 767-4         T 763  ☑ 763
#
# --------------------------------------------------
# Iteration 42
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 498us/step - loss: 0.0069 - acc: 0.9985 - val_loss: 0.0951 - val_acc: 0.9741
# Q 445+71b       T 516  ☑ 516
# Q 9-5           T 4    ☑ 4
# Q 44-2          T 42   ☑ 42
# Q 649+606ca     T 1255 ☒ 1235
# Q 835+72        T 907  ☑ 907
# Q 552-4z        T 548  ☑ 548
# Q 904-258zy     T 646  ☒ 666
# Q 2-0           T 2    ☑ 2
# Q 308+80        T 388  ☑ 388
# Q 67-3          T 64   ☑ 64
#
# --------------------------------------------------
# Iteration 43
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 511us/step - loss: 0.0160 - acc: 0.9956 - val_loss: 0.0910 - val_acc: 0.9729
# Q 904-258zy     T 646  ☒ 666
# Q 472+355b      T 827  ☑ 827
# Q 136-96y       T 40   ☒ 30
# Q 699+10        T 709  ☑ 709
# Q 43+24         T 67   ☑ 67
# Q 809+598ca     T 1407 ☒ 1417
# Q 664-65z       T 599  ☑ 599
# Q 66-0          T 66   ☑ 66
# Q 68+5c         T 73   ☑ 73
# Q 9-1           T 8    ☑ 8
#
# --------------------------------------------------
# Iteration 44
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 0.0080 - acc: 0.9981 - val_loss: 0.0871 - val_acc: 0.9764
# Q 83+2          T 85   ☑ 85
# Q 8-8           T 0    ☑ 0
# Q 928-6         T 922  ☑ 922
# Q 59+8c         T 67   ☑ 67
# Q 63+62b        T 125  ☑ 125
# Q 80+38b        T 118  ☒ 128
# Q 12+4          T 16   ☑ 16
# Q 75-1          T 74   ☑ 74
# Q 85-22         T 63   ☑ 63
# Q 72+31         T 103  ☑ 103
#
# --------------------------------------------------
# Iteration 45
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 0.0081 - acc: 0.9980 - val_loss: 0.0934 - val_acc: 0.9724
# Q 3-2           T 1    ☑ 1
# Q 872+836a      T 1708 ☒ 1608
# Q 223+54        T 277  ☑ 277
# Q 510-374zy     T 136  ☒ 226
# Q 570+44b       T 614  ☑ 614
# Q 47-9z         T 38   ☑ 38
# Q 318+70        T 388  ☑ 388
# Q 22+1          T 23   ☑ 23
# Q 7+3           T 10   ☑ 10
# Q 5-4           T 1    ☑ 1
#
# --------------------------------------------------
# Iteration 46
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 0.0085 - acc: 0.9978 - val_loss: 0.0917 - val_acc: 0.9743
# Q 577-20        T 557  ☑ 557
# Q 883-4z        T 879  ☑ 879
# Q 845+0         T 845  ☑ 845
# Q 69+6c         T 75   ☑ 75
# Q 550+264b      T 814  ☑ 814
# Q 33-7z         T 26   ☑ 26
# Q 78+6c         T 84   ☑ 84
# Q 20+0          T 20   ☑ 20
# Q 913+18c       T 931  ☑ 931
# Q 88-61         T 27   ☑ 27
#
# --------------------------------------------------
# Iteration 47
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 0.0045 - acc: 0.9992 - val_loss: 0.0862 - val_acc: 0.9766
# Q 823+87        T 910  ☒ 900
# Q 826+51        T 877  ☑ 877
# Q 236+92b       T 328  ☑ 328
# Q 407+92        T 499  ☑ 499
# Q 8+6c          T 14   ☑ 14
# Q 775-240       T 535  ☒ 555
# Q 223+54        T 277  ☑ 277
# Q 83+3          T 86   ☑ 86
# Q 5+3           T 8    ☑ 8
# Q 840-56zy      T 784  ☑ 784
#
# --------------------------------------------------
# Iteration 48
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 507us/step - loss: 0.0035 - acc: 0.9995 - val_loss: 0.0882 - val_acc: 0.9757
# Q 88-82         T 6    ☑ 6
# Q 64-0          T 64   ☑ 64
# Q 523-51y       T 472  ☑ 472
# Q 979-948       T 31   ☒ 11
# Q 168+3c        T 171  ☑ 171
# Q 577+5c        T 582  ☑ 582
# Q 74-5z         T 69   ☑ 69
# Q 397-2         T 395  ☑ 395
# Q 9-6           T 3    ☑ 3
# Q 9+3c          T 12   ☑ 12
#
# --------------------------------------------------
# Iteration 49
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 493us/step - loss: 0.0029 - acc: 0.9995 - val_loss: 0.0852 - val_acc: 0.9768
# Q 43+2          T 45   ☑ 45
# Q 946+611a      T 1557 ☒ 1527
# Q 703-53y       T 650  ☑ 650
# Q 345+87cb      T 432  ☑ 432
# Q 33+3          T 36   ☑ 36
# Q 169-35        T 134  ☑ 134
# Q 39+2c         T 41   ☑ 41
# Q 941-848z      T 93   ☒ 13
# Q 168+0         T 168  ☑ 168
# Q 909-4         T 905  ☑ 905
#
# --------------------------------------------------
# Iteration 50
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 493us/step - loss: 0.0101 - acc: 0.9973 - val_loss: 0.0950 - val_acc: 0.9731
# Q 441+84b       T 525  ☑ 525
# Q 488+0         T 488  ☑ 488
# Q 909-3         T 906  ☑ 906
# Q 101-59zy      T 42   ☒ 46
# Q 903-7z        T 896  ☑ 896
# Q 97-62         T 35   ☑ 35
# Q 40+9          T 49   ☑ 49
# Q 76+4          T 80   ☑ 80
# Q 544-40        T 504  ☒ 594
# Q 421-40y       T 381  ☑ 381
#
# --------------------------------------------------
# Iteration 51
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 492us/step - loss: 0.0094 - acc: 0.9976 - val_loss: 0.0931 - val_acc: 0.9744
# Q 561-29z       T 532  ☑ 532
# Q 149-8         T 141  ☑ 141
# Q 226-9z        T 217  ☑ 217
# Q 6-4           T 2    ☑ 2
# Q 11+2          T 13   ☑ 13
# Q 7-4           T 3    ☑ 3
# Q 694-3         T 691  ☑ 691
# Q 9+3c          T 12   ☑ 12
# Q 91-41         T 50   ☑ 50
# Q 511-281y      T 230  ☒ 220
#
# --------------------------------------------------
# Iteration 52
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 485us/step - loss: 0.0035 - acc: 0.9994 - val_loss: 0.0839 - val_acc: 0.9770
# Q 81-3z         T 78   ☑ 78
# Q 155-48z       T 107  ☑ 107
# Q 574-87zy      T 487  ☑ 487
# Q 77-2          T 75   ☑ 75
# Q 360+0         T 360  ☑ 360
# Q 926-339zy     T 587  ☒ 577
# Q 214+1         T 215  ☑ 215
# Q 47+2          T 49   ☑ 49
# Q 444-33        T 411  ☑ 411
# Q 3-1           T 2    ☑ 2
#
# --------------------------------------------------
# Iteration 53
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 494us/step - loss: 0.0059 - acc: 0.9985 - val_loss: 0.1140 - val_acc: 0.9689
# Q 148-2         T 146  ☑ 146
# Q 44+5          T 49   ☑ 49
# Q 85-23         T 62   ☑ 62
# Q 412+87        T 499  ☒ 489
# Q 825+3         T 828  ☑ 828
# Q 25-4          T 21   ☑ 21
# Q 693+2         T 695  ☑ 695
# Q 238+36c       T 274  ☑ 274
# Q 72+1          T 73   ☑ 73
# Q 740+53        T 793  ☑ 793
#
# --------------------------------------------------
# Iteration 54
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 0.0172 - acc: 0.9946 - val_loss: 0.1105 - val_acc: 0.9700
# Q 36+0          T 36   ☑ 36
# Q 994-248z      T 746  ☒ 756
# Q 902-8z        T 894  ☑ 894
# Q 10-7z         T 3    ☑ 3
# Q 583+3         T 586  ☑ 586
# Q 12-8z         T 4    ☑ 4
# Q 32+12         T 44   ☑ 44
# Q 19-2          T 17   ☑ 17
# Q 59+8c         T 67   ☑ 67
# Q 68-28         T 40   ☑ 40
#
# --------------------------------------------------
# Iteration 55
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 497us/step - loss: 0.0090 - acc: 0.9977 - val_loss: 0.0919 - val_acc: 0.9750
# Q 465-3         T 462  ☑ 462
# Q 58-0          T 58   ☑ 58
# Q 720+87        T 807  ☑ 807
# Q 813+48c       T 861  ☑ 861
# Q 89+69cb       T 158  ☑ 158
# Q 985+519ca     T 1504 ☒ 1304
# Q 241-48z       T 193  ☒ 293
# Q 54+3          T 57   ☑ 57
# Q 884-89z       T 795  ☑ 795
# Q 84+31b        T 115  ☑ 115
#
# --------------------------------------------------
# Iteration 56
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 501us/step - loss: 0.0049 - acc: 0.9987 - val_loss: 0.0911 - val_acc: 0.9755
# Q 52-51         T 1    ☑ 1
# Q 385+99cb      T 484  ☑ 484
# Q 520+24        T 544  ☑ 544
# Q 785+47cb      T 832  ☑ 832
# Q 934-8z        T 926  ☑ 926
# Q 79-62         T 17   ☑ 17
# Q 7+3           T 10   ☑ 10
# Q 4+0           T 4    ☑ 4
# Q 59+2c         T 61   ☑ 61
# Q 904-0         T 904  ☑ 904
#
# --------------------------------------------------
# Iteration 57
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 0.0028 - acc: 0.9995 - val_loss: 0.0901 - val_acc: 0.9763
# Q 65+63b        T 128  ☑ 128
# Q 9+7c          T 16   ☑ 16
# Q 625-26z       T 599  ☑ 599
# Q 57-1          T 56   ☑ 56
# Q 841+21        T 862  ☑ 862
# Q 677-33        T 644  ☑ 644
# Q 160-4z        T 156  ☑ 156
# Q 810-0         T 810  ☑ 810
# Q 9-7           T 2    ☑ 2
# Q 49+6c         T 55   ☑ 55
#
# --------------------------------------------------
# Iteration 58
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 0.0013 - acc: 0.9999 - val_loss: 0.0862 - val_acc: 0.9770
# Q 807+3         T 810  ☑ 810
# Q 745+37c       T 782  ☑ 782
# Q 899+7c        T 906  ☑ 906
# Q 7+4c          T 11   ☑ 11
# Q 746+89cb      T 835  ☑ 835
# Q 108+6c        T 114  ☑ 114
# Q 52-0          T 52   ☑ 52
# Q 35-5          T 30   ☑ 30
# Q 632-5z        T 627  ☑ 627
# Q 67-3          T 64   ☑ 64
#
# --------------------------------------------------
# Iteration 59
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 6.3754e-04 - acc: 1.0000 - val_loss: 0.0812 - val_acc: 0.9781
# Q 735-0         T 735  ☑ 735
# Q 879-31        T 848  ☑ 848
# Q 89-62         T 27   ☑ 27
# Q 80-11z        T 69   ☑ 69
# Q 567-37        T 530  ☑ 530
# Q 65-27z        T 38   ☑ 38
# Q 709-418y      T 291  ☒ 281
# Q 348+1         T 349  ☑ 349
# Q 41-3z         T 38   ☑ 38
# Q 424+240       T 664  ☒ 764
#
# --------------------------------------------------
# Iteration 60
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 504us/step - loss: 5.0225e-04 - acc: 1.0000 - val_loss: 0.0809 - val_acc: 0.9786
# Q 99+78cb       T 177  ☑ 177
# Q 957-0         T 957  ☑ 957
# Q 13+4          T 17   ☑ 17
# Q 902+4         T 906  ☑ 906
# Q 487+8c        T 495  ☑ 495
# Q 129+58c       T 187  ☑ 187
# Q 21+0          T 21   ☑ 21
# Q 32+6          T 38   ☑ 38
# Q 71+52b        T 123  ☑ 123
# Q 64-9z         T 55   ☑ 55
#
# --------------------------------------------------
# Iteration 61
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 4.3652e-04 - acc: 1.0000 - val_loss: 0.0816 - val_acc: 0.9785
# Q 78-8          T 70   ☑ 70
# Q 532-469zy     T 63   ☒ 73
# Q 91+2          T 93   ☑ 93
# Q 423+239c      T 662  ☒ 772
# Q 798+2         T 800  ☑ 800
# Q 992-9z        T 983  ☑ 983
# Q 162-11        T 151  ☑ 151
# Q 897+2         T 899  ☑ 899
# Q 867+491ba     T 1358 ☒ 1428
# Q 3-0           T 3    ☑ 3
#
# --------------------------------------------------
# Iteration 62
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 498us/step - loss: 4.0699e-04 - acc: 1.0000 - val_loss: 0.0799 - val_acc: 0.9785
# Q 842+95b       T 937  ☑ 937
# Q 65-47z        T 18   ☑ 18
# Q 44+11         T 55   ☑ 55
# Q 546+4         T 550  ☑ 550
# Q 397-2         T 395  ☑ 395
# Q 25-4          T 21   ☑ 21
# Q 3-1           T 2    ☑ 2
# Q 68+3c         T 71   ☑ 71
# Q 606+6c        T 612  ☑ 612
# Q 720+7         T 727  ☑ 727
#
# --------------------------------------------------
# Iteration 63
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 3.6136e-04 - acc: 1.0000 - val_loss: 0.0797 - val_acc: 0.9786
# Q 64+3          T 67   ☑ 67
# Q 55-4          T 51   ☑ 51
# Q 695-81        T 614  ☑ 614
# Q 853-674zy     T 179  ☑ 179
# Q 772-1         T 771  ☑ 771
# Q 39+8c         T 47   ☑ 47
# Q 63+1          T 64   ☑ 64
# Q 1-0           T 1    ☑ 1
# Q 64+5          T 69   ☑ 69
# Q 9+2c          T 11   ☑ 11
#
# --------------------------------------------------
# Iteration 64
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 3.4962e-04 - acc: 1.0000 - val_loss: 0.0789 - val_acc: 0.9790
# Q 924-8z        T 916  ☑ 916
# Q 53+1          T 54   ☑ 54
# Q 242+2         T 244  ☑ 244
# Q 412+47        T 459  ☑ 459
# Q 25-4          T 21   ☑ 21
# Q 975+660ba     T 1635 ☒ 1545
# Q 772+38        T 810  ☑ 810
# Q 63+5          T 68   ☑ 68
# Q 17+3          T 20   ☑ 20
# Q 666+5c        T 671  ☑ 671
#
# --------------------------------------------------
# Iteration 65
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 483us/step - loss: 2.9579e-04 - acc: 1.0000 - val_loss: 0.0807 - val_acc: 0.9788
# Q 950-8z        T 942  ☑ 942
# Q 308-7         T 301  ☑ 301
# Q 31+1          T 32   ☑ 32
# Q 9-7           T 2    ☑ 2
# Q 469+239c      T 708  ☒ 608
# Q 37-2          T 35   ☑ 35
# Q 287+71b       T 358  ☑ 358
# Q 769-23        T 746  ☑ 746
# Q 775+83b       T 858  ☑ 858
# Q 476+89cb      T 565  ☑ 565
#
# --------------------------------------------------
# Iteration 66
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 492us/step - loss: 0.0029 - acc: 0.9993 - val_loss: 0.1147 - val_acc: 0.9714
# Q 90+8          T 98   ☑ 98
# Q 32+2          T 34   ☑ 34
# Q 4-3           T 1    ☑ 1
# Q 18-4          T 14   ☑ 14
# Q 580-0         T 580  ☑ 580
# Q 935-7z        T 928  ☑ 928
# Q 4-4           T 0    ☑ 0
# Q 660-8z        T 652  ☑ 652
# Q 45+8c         T 53   ☑ 53
# Q 66-55         T 11   ☑ 11
#
# --------------------------------------------------
# Iteration 67
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 492us/step - loss: 0.0343 - acc: 0.9890 - val_loss: 0.1207 - val_acc: 0.9678
# Q 83+61b        T 144  ☑ 144
# Q 139-84y       T 55   ☒ 15
# Q 68+15c        T 83   ☑ 83
# Q 6+6c          T 12   ☑ 12
# Q 611+69        T 680  ☑ 680
# Q 92+1          T 93   ☑ 93
# Q 5-0           T 5    ☑ 5
# Q 57-18z        T 39   ☑ 39
# Q 484+2         T 486  ☑ 486
# Q 810-95zy      T 715  ☒ 725
#
# --------------------------------------------------
# Iteration 68
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 507us/step - loss: 0.0231 - acc: 0.9924 - val_loss: 0.0929 - val_acc: 0.9731
# Q 43+2          T 45   ☑ 45
# Q 217+4c        T 221  ☑ 221
# Q 5-2           T 3    ☑ 3
# Q 445+71b       T 516  ☑ 516
# Q 96-8z         T 88   ☑ 88
# Q 9-4           T 5    ☑ 5
# Q 469-65        T 404  ☑ 404
# Q 392+9c        T 401  ☑ 401
# Q 261-116z      T 145  ☑ 145
# Q 55+2          T 57   ☑ 57
#
# --------------------------------------------------
# Iteration 69
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 0.0093 - acc: 0.9973 - val_loss: 0.0884 - val_acc: 0.9756
# Q 6-5           T 1    ☑ 1
# Q 454-73y       T 381  ☑ 381
# Q 97-0          T 97   ☑ 97
# Q 40-28z        T 12   ☑ 12
# Q 67-23         T 44   ☑ 44
# Q 399+96cb      T 495  ☒ 405
# Q 748+625ca     T 1373 ☑ 1373
# Q 57+5c         T 62   ☑ 62
# Q 32+12         T 44   ☑ 44
# Q 63-8z         T 55   ☑ 55
#
# --------------------------------------------------
# Iteration 70
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 498us/step - loss: 0.0047 - acc: 0.9990 - val_loss: 0.0785 - val_acc: 0.9791
# Q 747+2         T 749  ☑ 749
# Q 10-7z         T 3    ☑ 3
# Q 8-2           T 6    ☑ 6
# Q 16-7z         T 9    ☑ 9
# Q 55-4          T 51   ☑ 51
# Q 649+6c        T 655  ☑ 655
# Q 79-21         T 58   ☑ 58
# Q 948-9z        T 939  ☑ 939
# Q 24-5z         T 19   ☑ 19
# Q 570+85b       T 655  ☑ 655
#
# --------------------------------------------------
# Iteration 71
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 501us/step - loss: 0.0018 - acc: 0.9998 - val_loss: 0.0783 - val_acc: 0.9791
# Q 83-75z        T 8    ☑ 8
# Q 3-1           T 2    ☑ 2
# Q 32-29z        T 3    ☑ 3
# Q 55-4          T 51   ☑ 51
# Q 951-2z        T 949  ☑ 949
# Q 99+70b        T 169  ☑ 169
# Q 41-2z         T 39   ☑ 39
# Q 55+2          T 57   ☑ 57
# Q 7-5           T 2    ☑ 2
# Q 207-8z        T 199  ☑ 199
#
# --------------------------------------------------
# Iteration 72
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 503us/step - loss: 9.5278e-04 - acc: 1.0000 - val_loss: 0.0791 - val_acc: 0.9795
# Q 7+6c          T 13   ☑ 13
# Q 875-2         T 873  ☑ 873
# Q 21+5          T 26   ☑ 26
# Q 672+642ba     T 1314 ☒ 1334
# Q 533-314z      T 219  ☒ 299
# Q 9-7           T 2    ☑ 2
# Q 92+20b        T 112  ☑ 112
# Q 722+84        T 806  ☑ 806
# Q 59+2c         T 61   ☑ 61
# Q 3-0           T 3    ☑ 3
#
# --------------------------------------------------
# Iteration 73
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 502us/step - loss: 7.9830e-04 - acc: 1.0000 - val_loss: 0.0798 - val_acc: 0.9789
# Q 213-57zy      T 156  ☑ 156
# Q 153-2         T 151  ☑ 151
# Q 77+36c        T 113  ☑ 113
# Q 815+1         T 816  ☑ 816
# Q 67+33         T 100  ☑ 100
# Q 47-2          T 45   ☑ 45
# Q 448-8         T 440  ☑ 440
# Q 194+69cb      T 263  ☑ 263
# Q 34-4          T 30   ☑ 30
# Q 577-20        T 557  ☑ 557
#
# --------------------------------------------------
# Iteration 74
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 7.1937e-04 - acc: 0.9999 - val_loss: 0.0788 - val_acc: 0.9803
# Q 660-8z        T 652  ☑ 652
# Q 672-7z        T 665  ☑ 665
# Q 808+353ca     T 1161 ☒ 1171
# Q 55+2          T 57   ☑ 57
# Q 88-71         T 17   ☑ 17
# Q 83-0          T 83   ☑ 83
# Q 6+3           T 9    ☑ 9
# Q 5-3           T 2    ☑ 2
# Q 89-62         T 27   ☑ 27
# Q 4+4           T 8    ☑ 8
#
# --------------------------------------------------
# Iteration 75
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 506us/step - loss: 6.8122e-04 - acc: 0.9999 - val_loss: 0.0828 - val_acc: 0.9785
# Q 62+8          T 70   ☑ 70
# Q 648-14        T 634  ☑ 634
# Q 722-91y       T 631  ☑ 631
# Q 514+0         T 514  ☑ 514
# Q 74-30         T 44   ☑ 44
# Q 22+1          T 23   ☑ 23
# Q 842-6z        T 836  ☑ 836
# Q 51-0          T 51   ☑ 51
# Q 9+8c          T 17   ☑ 17
# Q 515-4         T 511  ☑ 511
#
# --------------------------------------------------
# Iteration 76
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 499us/step - loss: 7.6041e-04 - acc: 0.9999 - val_loss: 0.0796 - val_acc: 0.9810
# Q 995-1         T 994  ☑ 994
# Q 97-0          T 97   ☑ 97
# Q 5-0           T 5    ☑ 5
# Q 3-2           T 1    ☑ 1
# Q 415-11        T 404  ☑ 404
# Q 2-1           T 1    ☑ 1
# Q 115+5         T 120  ☑ 120
# Q 833+39c       T 872  ☑ 872
# Q 45-5          T 40   ☑ 40
# Q 426+5c        T 431  ☑ 431
#
# --------------------------------------------------
# Iteration 77
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 5.4201e-04 - acc: 0.9999 - val_loss: 0.0798 - val_acc: 0.9798
# Q 546-0         T 546  ☑ 546
# Q 89-62         T 27   ☑ 27
# Q 120-70y       T 50   ☑ 50
# Q 160-4z        T 156  ☑ 156
# Q 597+37cb      T 634  ☑ 634
# Q 931+358a      T 1289 ☒ 1299
# Q 3-1           T 2    ☑ 2
# Q 318+70        T 388  ☑ 388
# Q 751-74zy      T 677  ☑ 677
# Q 9-2           T 7    ☑ 7
#
# --------------------------------------------------
# Iteration 78
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 480us/step - loss: 0.0047 - acc: 0.9986 - val_loss: 0.0998 - val_acc: 0.9741
# Q 12-4z         T 8    ☑ 8
# Q 65-51         T 14   ☑ 14
# Q 511-281y      T 230  ☒ 320
# Q 786-3         T 783  ☑ 783
# Q 96+4          T 100  ☑ 100
# Q 387+14c       T 401  ☑ 401
# Q 65-19z        T 46   ☑ 46
# Q 504+0         T 504  ☑ 504
# Q 35-8z         T 27   ☑ 27
# Q 384+7c        T 391  ☑ 391
#
# --------------------------------------------------
# Iteration 79
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 492us/step - loss: 0.0161 - acc: 0.9955 - val_loss: 0.1124 - val_acc: 0.9697
# Q 41-29z        T 12   ☑ 12
# Q 97+11         T 108  ☑ 108
# Q 422-53zy      T 369  ☑ 369
# Q 825+5         T 830  ☑ 830
# Q 901+637a      T 1538 ☑ 1538
# Q 936+74        T 1010 ☑ 1010
# Q 981+25        T 1006 ☑ 1006
# Q 4+3           T 7    ☑ 7
# Q 577-20        T 557  ☑ 557
# Q 87+2          T 89   ☑ 89
#
# --------------------------------------------------
# Iteration 80
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 494us/step - loss: 0.0152 - acc: 0.9953 - val_loss: 0.0999 - val_acc: 0.9711
# Q 29+3c         T 32   ☑ 32
# Q 175+5         T 180  ☑ 180
# Q 798+2         T 800  ☑ 800
# Q 433-6z        T 427  ☑ 427
# Q 348+1         T 349  ☑ 349
# Q 6-0           T 6    ☑ 6
# Q 340+122       T 462  ☑ 462
# Q 8+0           T 8    ☑ 8
# Q 356+61b       T 417  ☑ 417
# Q 948-9z        T 939  ☑ 939
#
# --------------------------------------------------
# Iteration 81
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 0.0067 - acc: 0.9981 - val_loss: 0.0912 - val_acc: 0.9741
# Q 7-0           T 7    ☑ 7
# Q 227-4         T 223  ☑ 223
# Q 711-91y       T 620  ☑ 620
# Q 786-3         T 783  ☑ 783
# Q 85-7z         T 78   ☑ 78
# Q 989-98y       T 891  ☑ 891
# Q 233-1         T 232  ☑ 232
# Q 290+4         T 294  ☑ 294
# Q 39+8c         T 47   ☑ 47
# Q 412+41        T 453  ☒ 463
#
# --------------------------------------------------
# Iteration 82
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 500us/step - loss: 0.0035 - acc: 0.9992 - val_loss: 0.0883 - val_acc: 0.9780
# Q 15-9z         T 6    ☑ 6
# Q 64-2          T 62   ☑ 62
# Q 941-41        T 900  ☑ 900
# Q 740+25        T 765  ☑ 765
# Q 185+28c       T 213  ☑ 213
# Q 41-2z         T 39   ☑ 39
# Q 72-0          T 72   ☑ 72
# Q 6+3           T 9    ☑ 9
# Q 155+23        T 178  ☑ 178
# Q 66+4          T 70   ☑ 70
#
# --------------------------------------------------
# Iteration 83
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 0.0023 - acc: 0.9995 - val_loss: 0.0840 - val_acc: 0.9778
# Q 19+5c         T 24   ☑ 24
# Q 304-8z        T 296  ☑ 296
# Q 20+0          T 20   ☑ 20
# Q 58-0          T 58   ☑ 58
# Q 7-4           T 3    ☑ 3
# Q 630-28z       T 602  ☑ 602
# Q 566+4         T 570  ☑ 570
# Q 41-2z         T 39   ☑ 39
# Q 7+6c          T 13   ☑ 13
# Q 66+9c         T 75   ☑ 75
#
# --------------------------------------------------
# Iteration 84
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 0.0010 - acc: 0.9999 - val_loss: 0.0773 - val_acc: 0.9789
# Q 99+70b        T 169  ☑ 169
# Q 792-7z        T 785  ☑ 785
# Q 47+2          T 49   ☑ 49
# Q 917+6c        T 923  ☑ 923
# Q 921-90y       T 831  ☑ 831
# Q 875-2         T 873  ☑ 873
# Q 720+87        T 807  ☑ 807
# Q 689+98cb      T 787  ☑ 787
# Q 606+7c        T 613  ☑ 613
# Q 92+7          T 99   ☑ 99
#
# --------------------------------------------------
# Iteration 85
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 496us/step - loss: 0.0013 - acc: 0.9998 - val_loss: 0.0835 - val_acc: 0.9787
# Q 41-29z        T 12   ☑ 12
# Q 60-33z        T 27   ☑ 27
# Q 76+4          T 80   ☑ 80
# Q 75+53b        T 128  ☑ 128
# Q 16-5          T 11   ☑ 11
# Q 96-72         T 24   ☑ 24
# Q 783-70        T 713  ☑ 713
# Q 570+46b       T 616  ☑ 616
# Q 93+5          T 98   ☑ 98
# Q 43-9z         T 34   ☑ 34
#
# --------------------------------------------------
# Iteration 86
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 490us/step - loss: 0.0011 - acc: 0.9998 - val_loss: 0.0719 - val_acc: 0.9802
# Q 226-9z        T 217  ☑ 217
# Q 6-5           T 1    ☑ 1
# Q 6+6c          T 12   ☑ 12
# Q 60-24z        T 36   ☑ 36
# Q 20-2z         T 18   ☑ 18
# Q 168+8c        T 176  ☑ 176
# Q 139+85cb      T 224  ☑ 224
# Q 73-0          T 73   ☑ 73
# Q 717-3         T 714  ☑ 714
# Q 54+3          T 57   ☑ 57
#
# --------------------------------------------------
# Iteration 87
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 481us/step - loss: 6.1574e-04 - acc: 0.9999 - val_loss: 0.0751 - val_acc: 0.9788
# Q 880-157z      T 723  ☒ 733
# Q 15+5          T 20   ☑ 20
# Q 270+226       T 496  ☑ 496
# Q 828-526       T 302  ☒ 312
# Q 69-36         T 33   ☑ 33
# Q 1-0           T 1    ☑ 1
# Q 303-4z        T 299  ☑ 299
# Q 17+2          T 19   ☑ 19
# Q 30+7          T 37   ☑ 37
# Q 2-2           T 0    ☑ 0
#
# --------------------------------------------------
# Iteration 88
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 482us/step - loss: 3.5811e-04 - acc: 1.0000 - val_loss: 0.0749 - val_acc: 0.9801
# Q 45+8c         T 53   ☑ 53
# Q 576+65cb      T 641  ☑ 641
# Q 999-6         T 993  ☑ 993
# Q 518+3c        T 521  ☑ 521
# Q 809+620a      T 1429 ☒ 1419
# Q 73-9z         T 64   ☑ 64
# Q 25+5          T 30   ☑ 30
# Q 821-21        T 800  ☑ 800
# Q 833+39c       T 872  ☑ 872
# Q 12+3          T 15   ☑ 15
#
# --------------------------------------------------
# Iteration 89
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 495us/step - loss: 2.9110e-04 - acc: 1.0000 - val_loss: 0.0754 - val_acc: 0.9801
# Q 81-7z         T 74   ☑ 74
# Q 662+7         T 669  ☑ 669
# Q 810-0         T 810  ☑ 810
# Q 424+240       T 664  ☒ 764
# Q 6-5           T 1    ☑ 1
# Q 93+44b        T 137  ☑ 137
# Q 843-6z        T 837  ☑ 837
# Q 22+9c         T 31   ☑ 31
# Q 99+69cb       T 168  ☑ 168
# Q 935-42y       T 893  ☑ 893
#
# --------------------------------------------------
# Iteration 90
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 493us/step - loss: 2.5858e-04 - acc: 1.0000 - val_loss: 0.0754 - val_acc: 0.9800
# Q 553+92b       T 645  ☑ 645
# Q 84+2          T 86   ☑ 86
# Q 946+611a      T 1557 ☒ 1547
# Q 53-7z         T 46   ☑ 46
# Q 876+408ca     T 1284 ☒ 1274
# Q 905-375y      T 530  ☑ 530
# Q 990+691ba     T 1681 ☒ 1871
# Q 869+44c       T 913  ☑ 913
# Q 9+8c          T 17   ☑ 17
# Q 221+6         T 227  ☑ 227
#
# --------------------------------------------------
# Iteration 91
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 484us/step - loss: 2.6011e-04 - acc: 1.0000 - val_loss: 0.0783 - val_acc: 0.9796
# Q 14-7z         T 7    ☑ 7
# Q 5-5           T 0    ☑ 0
# Q 967+722a      T 1689 ☒ 1659
# Q 125+122       T 247  ☒ 347
# Q 85-34         T 51   ☑ 51
# Q 29+5c         T 34   ☑ 34
# Q 925+181       T 1106 ☑ 1106
# Q 962+2         T 964  ☑ 964
# Q 73+4          T 77   ☑ 77
# Q 510-374zy     T 136  ☒ 266
#
# --------------------------------------------------
# Iteration 92
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 492us/step - loss: 0.0010 - acc: 0.9998 - val_loss: 0.0888 - val_acc: 0.9774
# Q 628+98cb      T 726  ☒ 736
# Q 728-58y       T 670  ☑ 670
# Q 917+6c        T 923  ☑ 923
# Q 248-97y       T 151  ☑ 151
# Q 9-2           T 7    ☑ 7
# Q 21+0          T 21   ☑ 21
# Q 52-2          T 50   ☑ 50
# Q 205+91        T 296  ☑ 296
# Q 786-3         T 783  ☑ 783
# Q 115+5         T 120  ☑ 120
#
# --------------------------------------------------
# Iteration 93
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 490us/step - loss: 0.0023 - acc: 0.9994 - val_loss: 0.0851 - val_acc: 0.9784
# Q 497-66        T 431  ☑ 431
# Q 92+1          T 93   ☑ 93
# Q 765-106z      T 659  ☑ 659
# Q 266+1         T 267  ☑ 267
# Q 52-5z         T 47   ☑ 47
# Q 550+264b      T 814  ☑ 814
# Q 2-1           T 1    ☑ 1
# Q 87+79cb       T 166  ☑ 166
# Q 99+91b        T 190  ☑ 190
# Q 91+9          T 100  ☑ 100
#
# --------------------------------------------------
# Iteration 94
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 490us/step - loss: 0.0171 - acc: 0.9947 - val_loss: 0.1261 - val_acc: 0.9660
# Q 207-91y       T 116  ☑ 116
# Q 33+1          T 34   ☑ 34
# Q 6-0           T 6    ☑ 6
# Q 219+30        T 249  ☑ 249
# Q 454-73y       T 381  ☑ 381
# Q 958+461ba     T 1419 ☒ 1329
# Q 422-53zy      T 369  ☑ 369
# Q 552-4z        T 548  ☑ 548
# Q 59+58c        T 117  ☑ 117
# Q 85-71         T 14   ☑ 14
#
# --------------------------------------------------
# Iteration 95
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 502us/step - loss: 0.0200 - acc: 0.9935 - val_loss: 0.0926 - val_acc: 0.9764
# Q 250+3         T 253  ☑ 253
# Q 67-23         T 44   ☑ 44
# Q 810-95zy      T 715  ☑ 715
# Q 634+76        T 710  ☑ 710
# Q 641+371b      T 1012 ☒ 9022
# Q 952-362y      T 590  ☑ 590
# Q 105-84y       T 21   ☑ 21
# Q 577-20        T 557  ☑ 557
# Q 71+4          T 75   ☑ 75
# Q 7+6c          T 13   ☑ 13
#
# --------------------------------------------------
# Iteration 96
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 497us/step - loss: 0.0068 - acc: 0.9981 - val_loss: 0.0899 - val_acc: 0.9768
# Q 7-5           T 2    ☑ 2
# Q 6-5           T 1    ☑ 1
# Q 4+3           T 7    ☑ 7
# Q 785-94y       T 691  ☑ 691
# Q 32-3z         T 29   ☑ 29
# Q 7-4           T 3    ☑ 3
# Q 88+0          T 88   ☑ 88
# Q 65-47z        T 18   ☑ 18
# Q 236+92b       T 328  ☑ 328
# Q 741-17z       T 724  ☑ 724
#
# --------------------------------------------------
# Iteration 97
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 498us/step - loss: 0.0037 - acc: 0.9989 - val_loss: 0.0894 - val_acc: 0.9776
# Q 367-297y      T 70   ☒ 80
# Q 286-6         T 280  ☑ 280
# Q 765-667z      T 98   ☒ 18
# Q 3+1           T 4    ☑ 4
# Q 6-1           T 5    ☑ 5
# Q 625+89c       T 714  ☑ 714
# Q 940-0         T 940  ☑ 940
# Q 6-4           T 2    ☑ 2
# Q 949-60y       T 889  ☑ 889
# Q 254-2         T 252  ☑ 252
#
# --------------------------------------------------
# Iteration 98
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 498us/step - loss: 0.0019 - acc: 0.9997 - val_loss: 0.0853 - val_acc: 0.9790
# Q 65-4          T 61   ☑ 61
# Q 10-7z         T 3    ☑ 3
# Q 807+683a      T 1490 ☒ 1470
# Q 25+9c         T 34   ☑ 34
# Q 439-3         T 436  ☑ 436
# Q 487+8c        T 495  ☑ 495
# Q 96+1          T 97   ☑ 97
# Q 995-1         T 994  ☑ 994
# Q 44+3          T 47   ☑ 47
# Q 482-60        T 422  ☑ 422
#
# --------------------------------------------------
# Iteration 99
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/1
# 18000/18000 [==============================] - 9s 498us/step - loss: 9.8958e-04 - acc: 0.9998 - val_loss: 0.0862 - val_acc: 0.9782
# Q 190+8         T 198  ☑ 198
# Q 175-2         T 173  ☑ 173
# Q 226-9z        T 217  ☑ 217
# Q 72-1          T 71   ☑ 71
# Q 72-0          T 72   ☑ 72
# Q 877+5c        T 882  ☑ 882
# Q 39-6          T 33   ☑ 33
# Q 503-57zy      T 446  ☑ 446
# Q 868+131       T 999  ☒ 909
# Q 144-88zy      T 56   ☒ 46

# %% [markdown]
# ## Save Model

# %%
# model.save('BiLSTM.h5')

# %% [markdown]
# ## Validation

# %%
right = 0
preds = model.predict_classes(test_x, verbose=0)
for i in range(len(preds)):
    q = ctable.decode(test_x[i])
    correct = ctable.decode(test_y[i])
    guess = ctable.decode(preds[i], calc_argmax=False)
#     print('Q', q[::-1] if REVERSE else q, end=' ')
#     print('T', correct, end=' ')
    if correct == guess:
#         print(colors.ok + '☑' + colors.close, end=' ')
        right += 1
#     else:
#         print(colors.fail + '☒' + colors.close, end=' ')
#     print(guess)
print("MSG : Accuracy is {}".format(right / len(preds)))
# Out:
# MSG : Accuracy is 0.9348166666666666
